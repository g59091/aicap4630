# %% [markdown]
# ## Three dimensional plots

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
def f1(x, y):
    return (x**2 + y + 1000)
def f2(x, y):
    return (y**3 - x)
def f3(x, y):
    return (x**3 + (y**3 - 1000) - 1000)
ax = plt.axes(projection='3d')
xline = np.linspace(0, 15, 10)
yline = np.linspace(0, 15, 10)
z1line = f1(xline, yline)
ax.plot3D(xline, yline, z1line, 'gray')
p1x = np.array([0])
p1y = np.array([0])
p1z = f1(p1x, p1y)
plt.plot(p1x, p1y, p1z, 'yo')
#ax.view_init(35, 15)

z2line = f2(xline, yline)
ax.plot3D(xline, yline, z2line, 'green')
p2x = np.array([15])
p2y = np.array([15])
p2z = f2(p2x, p2y)
plt.plot(p2x, p2y, p2z, 'bo')

z3line = f3(xline, yline)
ax.plot3D(xline, yline, z3line, 'blue')
p3x = np.array([3])
p3y = np.array([3])
p3z = f3(p3x, p3y)
plt.plot(p3x, p3y, p3z, 'ro')

# %% [markdown]
# ## Contour plots

# %%
plt.style.use('seaborn-white')
X, Y = np.meshgrid(xline, yline)
Z1 = f1(X, Y)
plt.contour(X, Y, Z1, colors='black')
p1x = np.array([0])
p1y = np.array([0])
p1z = f1(p1x, p1y)
plt.plot(p1x, p1y, p1z, 'ro')
# Out:
# [<matplotlib.lines.Line2D at 0x7f919528aef0>,
#  <matplotlib.lines.Line2D at 0x7f919525f668>]

# %%
Z2 = f2(X, Y)
plt.contour(X, Y, Z2, colors='black')
p2x = np.array([15])
p2y = np.array([15])
p2z = f2(p2x, p2y)
plt.plot(p2x, p2y, p2z, 'ro')
# Out:
# [<matplotlib.lines.Line2D at 0x7f9195381240>,
#  <matplotlib.lines.Line2D at 0x7f91952ec940>]

# %%
Z3 = f3(X, Y)
plt.contour(X, Y, Z3, colors='black')
p3x = np.array([3])
p3y = np.array([3])
p3z = f3(p3x, p3y)
plt.plot(p3x, p3y, p3z, 'ro')
# Out:
# [<matplotlib.lines.Line2D at 0x7f91954852e8>,
#  <matplotlib.lines.Line2D at 0x7f9195373a90>]

# %% [markdown]
# ## Density plots

# %%
Z1 = f1(X, Y)
plt.contour(X, Y, Z1, 20, cmap='RdGy')
plt.colorbar()
p1x = np.array([0])
p1y = np.array([0])
p1z = f1(p1x, p1y)
plt.plot(p1x, p1y, p1z, 'ro')
# Out:
# [<matplotlib.lines.Line2D at 0x7f9195406550>,
#  <matplotlib.lines.Line2D at 0x7f9195406710>]

# %%
Z2 = f2(X, Y)
plt.contour(X, Y, Z2, 20, cmap='RdGy')
plt.colorbar()
p2x = np.array([15])
p2y = np.array([15])
p2z = f2(p2x, p2y)
plt.plot(p2x, p2y, p2z, 'ro')
# Out:
# [<matplotlib.lines.Line2D at 0x7f919549afd0>,
#  <matplotlib.lines.Line2D at 0x7f91954a3278>]

# %%
Z3 = f3(X, Y)
plt.contour(X, Y, Z3, 20, cmap='RdGy')
plt.colorbar()
p3x = np.array([3])
p3y = np.array([3])
p3z = f3(p3x, p3y)
plt.plot(p3x, p3y, p3z, 'ro')
# Out:
# [<matplotlib.lines.Line2D at 0x7f91955bc9e8>,
#  <matplotlib.lines.Line2D at 0x7f91955bcba8>]
