# %% [markdown]
# <a href="https://colab.research.google.com/github/g59091/aicap4630/blob/master/HW3/HW_3Problem_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2>Setting up imports...</h2>

# %%
# %tensorflow_version 2.x
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import random
import tensorflow as tf
from tensorflow import keras
print(tf.__version__)
print(keras.__version__)
print(np.__version__)
# Out:
# 2.2.0-rc2
# 2.3.0-tf
# 1.18.2

# %% [markdown]
# <h2>...Defining the function to construct random data...</h2>

# %%
def get_random_data(w, b, mu, sigma, m):
    data, labels = np.zeros((m, 2)), np.zeros((m, 1), dtype=int)
    for i in range(m):
        c = random.randrange(0, 2)
        x_1 = random.random()
        n = np.random.default_rng().normal(mu, sigma, 1)
        x_2 = w * x_1 + b + (-1)**c * n
        data[i, 0], data[i, 1] = x_1, x_2
        labels[i] = c
    return (data, labels)

# %% [markdown]
# <h2>... And printing out the data.</h2>

# %%
def display_random_data(labels, data):
    datax, datay = np.split(data,[-1], axis = 1)
    pltclrs = ['red' if val == 1 else 'blue' for val in labels]
    plt.scatter(datax, datay, c = pltclrs)
    plt.title('Random Log. Reg. Data Gen.')
    plt.xlabel('x_1')
    plt.ylabel('x_2')
    plt.show()

data, labels = get_random_data(20, 10, 20, 6, 5000)
print("data.shape is", data.shape)
print("labels.shape is", labels.shape)
display_random_data(labels, data)
# Out:
# data.shape is (5000, 2)
# labels.shape is (5000, 1)

# %% [markdown]
# <h2>(Exporting data to the other hw problems)</h2>

# %%
traindata, testdata = np.split(data, [int(0.8 * data.shape[0])])
trainlbl, testlbl = np.split(labels, [int(0.8 * labels.shape[0])])

def get_train_set():
    return (traindata, trainlbl)
def get_test_set():
    return (testdata, testlbl)
